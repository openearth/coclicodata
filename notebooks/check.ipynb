# %% [markdown]
# ## Script to quickly check datasets in the catalog

# %%
import pystac_client
import pathlib
import xarray as xr

# %%
str(pathlib.Path().home().joinpath(r"Documents\GitHub\coclicodata\current\catalog.json"))
# Out:
# 'C:\\Users\\kras\\Documents\\GitHub\\coclicodata\\current\\catalog.json'

# %%
catalog = pystac_client.Client.open(
    "https://storage.googleapis.com/dgds-data-public/coclico/coclico-stac/catalog.json" # cloud API
    #r"p:\1000545-054-globalbeaches\15_GlobalCoastalAtlas\coclicodata\current\catalog.json" # P drive API 
    #r"https://storage.googleapis.com/EMODnet_geology/current/catalog.json" # fake link for emodnet presentation
    #r"C:\Users\kras\Documents\GitHub\coclicodata\current\catalog.json" # C drive API, local clone of https://github.com/openearth/coclicodata/tree/GCA/current
)

# %%
list(catalog.get_children())
# Out:
# [<CollectionClient id=ssl>,
#  <CollectionClient id=wef>,
#  <CollectionClient id=eesl>,
#  <CollectionClient id=floodmaps>,
#  <CollectionClient id=sc>,
#  <CollectionClient id=cbca>,
#  <CollectionClient id=cfr>,
#  <CollectionClient id=cm>,
#  <CollectionClient id=smd>,
#  <CollectionClient id=cisi>,
#  <CollectionClient id=slp5>,
#  <CollectionClient id=slp6>]

# %%
href = catalog.get_child("eesl").assets["data"].href
ds = xr.open_zarr(href)
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (nscenarios: 2, stations: 11014, rp: 8, time: 11, nensemble: 3)
# Coordinates:
#     ensemble   (nensemble) |S4 dask.array<chunksize=(3,), meta=np.ndarray>
#     lat        (stations) float64 dask.array<chunksize=(11014,), meta=np.ndarray>
#     lon        (stations) float64 dask.array<chunksize=(11014,), meta=np.ndarray>
#   * rp         (rp) float32 5.0 10.0 20.0 50.0 100.0 200.0 500.0 1e+03
#     scenarios  (nscenarios) |S5 dask.array<chunksize=(2,), meta=np.ndarray>
#   * time       (time) float32 1.995e+03 2.01e+03 2.02e+03 ... 2.09e+03 2.1e+03
# Dimensions without coordinates: nscenarios, stations, nensemble
# Data variables:
#     eewl       (nscenarios, stations, rp, time, nensemble) float64 dask.array<chunksize=(1, 2754, 4, 6, 2), meta=np.ndarray>
#     esl        (nscenarios, stations, rp, time, nensemble) float64 dask.array<chunksize=(1, 2754, 4, 6, 2), meta=np.ndarray>
# Attributes: (12/13)
#     Conventions:      CF-1.8
# ...

# %%
ds["nensemble"].values
# Out:
# array([0, 1, 2], dtype=int64)
