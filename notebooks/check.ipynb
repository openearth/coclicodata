# %% [markdown]
# ## Script to quickly check datasets in the catalog

# %%
import pystac_client
import pathlib
import xarray as xr

# %%
str(pathlib.Path().home().joinpath(r"Documents\GitHub\coclicodata\current\catalog.json"))
# Out:
# 'C:\\Users\\kras\\Documents\\GitHub\\coclicodata\\current\\catalog.json'

# %%
catalog = pystac_client.Client.open(
    "https://storage.googleapis.com/coclico-data-public/coclico/coclico-stac/catalog.json" # cloud API
    #r"C:\Users\kras\Documents\GitHub\coclicodata\current\catalog.json" # C drive API
)
# Out:
# c:\Users\kras\AppData\Local\mambaforge\envs\coclico\Lib\site-packages\pystac_client\client.py:187: NoConformsTo: Server does not advertise any conformance classes.
#   warnings.warn(NoConformsTo())

# %%
catalog2 = pystac_client.Client.open(
    "https://storage.googleapis.com/dgds-data-public/gca/gca-stac/catalog.json" # cloud API
    #r"C:\Users\kras\Documents\GitHub\global-coastal-atlas\stac_folder\current\catalog.json" # C drive API
)

# %%
list(catalog.get_children())
# Out:
# [<CollectionClient id=ssl>,
#  <CollectionClient id=wef>,
#  <CollectionClient id=eesl>,
#  <CollectionClient id=floodmaps>,
#  <CollectionClient id=sc>,
#  <CollectionClient id=cbca>,
#  <CollectionClient id=coastal-mask>,
#  <CollectionClient id=smd>,
#  <CollectionClient id=cisi>,
#  <CollectionClient id=slp5>,
#  <CollectionClient id=slp6>,
#  <CollectionClient id=cfr>,
#  <CollectionClient id=slp6_pilot>]

# %%
list(catalog2.get_children())
# Out:
# [<CollectionClient id=shore_mon_fut>,
#  <CollectionClient id=sed_class>,
#  <CollectionClient id=shore_mon>,
#  <CollectionClient id=world_pop>,
#  <CollectionClient id=world_gdp>,
#  <CollectionClient id=shore_mon_hr>,
#  <CollectionClient id=shore_mon_drivers>,
#  <CollectionClient id=esl_gwl>]

# %%
href = catalog.get_child("ssl").assets["data"].href
ds = xr.open_zarr(href)
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (stations: 2242, rp: 8, nscenarios: 3)
# Coordinates:
#     lat        (stations) float64 dask.array<chunksize=(2242,), meta=np.ndarray>
#     lon        (stations) float64 dask.array<chunksize=(2242,), meta=np.ndarray>
#   * rp         (rp) float32 5.0 10.0 20.0 50.0 100.0 200.0 500.0 1e+03
#     scenarios  (nscenarios) |S10 dask.array<chunksize=(3,), meta=np.ndarray>
# Dimensions without coordinates: stations, nscenarios
# Data variables:
#     ssl        (nscenarios, stations, rp) float64 dask.array<chunksize=(2, 2242, 8), meta=np.ndarray>
# Attributes: (12/13)
#     Conventions:      CF-1.8
#     End_date:         30-Nov-2004 21:00:00
#     Institution:      Joint European Research Center, Institute of Environmen...
#     Project_Acronym:  CoastAlRisk
#     Project_Name:     Prototype of a first Global Integrated Coastal Impact-b...
#     Starting_date:    01-Dec-1969
#     ...               ...
# ...

# %%
href = catalog.get_child("slp6_pilot").assets["data"].href
ds = xr.open_zarr(href)
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (nensemble: 3, nstations: 4, nscenarios: 4, time: 4)
# Coordinates:
#     ensemble   (nensemble) |S6 dask.array<chunksize=(3,), meta=np.ndarray>
#     lat        (nstations) float64 dask.array<chunksize=(4,), meta=np.ndarray>
#     lon        (nstations) float64 dask.array<chunksize=(4,), meta=np.ndarray>
#     scenarios  (nscenarios) |S6 dask.array<chunksize=(4,), meta=np.ndarray>
#     stations   (nstations) |S12 dask.array<chunksize=(4,), meta=np.ndarray>
#   * time       (time) int64 2030 2050 2100 2150
# Dimensions without coordinates: nensemble, nstations, nscenarios
# Data variables:
#     slr        (nstations, nscenarios, nensemble, time) float64 dask.array<chunksize=(4, 4, 3, 4), meta=np.ndarray>
# Attributes: (12/21)
#     AUTHOR:              to be done later...
#     CITATION:            to be done later...
#     COMMENT:             test is in the works
#     CRS:                 EPSG:4326
#     Conventions:         CF-1.8
# ...

# %%
href = catalog2.get_child("shore_mon").assets["data"].href
ds = xr.open_zarr(href)
ds
#ds["stations"].values
# Out:
# <xarray.Dataset>
# Dimensions:             (stations: 1837203, time: 38)
# Coordinates: (12/18)
#     coastline_idint     (stations) float64 dask.array<chunksize=(57413,), meta=np.ndarray>
#     continent           (stations) |S23 dask.array<chunksize=(28707,), meta=np.ndarray>
#     country             (stations) |S40 dask.array<chunksize=(28707,), meta=np.ndarray>
#     country_id          (stations) |S7 dask.array<chunksize=(114826,), meta=np.ndarray>
#     err_changerate      (stations) float64 dask.array<chunksize=(57413,), meta=np.ndarray>
#     err_timespan        (stations) float64 dask.array<chunksize=(57413,), meta=np.ndarray>
#     ...                  ...
#     no_shorelines       (stations) float64 dask.array<chunksize=(57413,), meta=np.ndarray>
#     rmse                (stations) float64 dask.array<chunksize=(57413,), meta=np.ndarray>
#   * time                (time) datetime64[ns] 1984-01-01 ... 2021-01-01
# ...

# %%
href = catalog.get_child("cfr").assets["data"].href
ds = xr.open_zarr(href)
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (nscenarios: 3, stations: 24, time: 3)
# Coordinates:
#     geometry   (stations) |S17480 dask.array<chunksize=(12,), meta=np.ndarray>
#     lat        (stations) float64 dask.array<chunksize=(24,), meta=np.ndarray>
#     lon        (stations) float64 dask.array<chunksize=(24,), meta=np.ndarray>
#     scenarios  (nscenarios) |S11 dask.array<chunksize=(3,), meta=np.ndarray>
#   * time       (time) int32 2000 2050 2100
# Dimensions without coordinates: nscenarios, stations
# Data variables:
#     ead        (nscenarios, stations, time) float64 dask.array<chunksize=(3, 24, 3), meta=np.ndarray>
#     ead_gdp    (nscenarios, stations, time) float64 dask.array<chunksize=(3, 24, 3), meta=np.ndarray>
#     eapa       (nscenarios, stations, time) float64 dask.array<chunksize=(3, 24, 3), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.8
#     crs:          4326
#     description:  Ensemble median Expected Annual Damage (expressed in billio...
# ...
